# %% [markdown]
# # Bibliotecas populares de Python
#
# ## Índice
# 1. [Asyncio](#asyncio)
# 2. [Beautiful Soup](#beautiful-soup)
# 3. [Bokeh](#bokeh)
# 4. [Dash](#dash)
# 5. [Django](#django)
# 6. [Flask](#flask)
# 7. [Hugging Face Transformers](#hugging-face-transformers)
# 8. [Keras](#keras)
# 9. [Matplotlib](#matplotlib)
# 10. [NLTK (Natural Language Toolkit)](#nltk-natural-language-toolkit)
# 11. [NumPy](#numpy)
# 12. [OpenCV](#opencv)
# 13. [Pandas](#pandas)
# 14. [Pillow](#pillow)
# 15. [Plotly](#plotly)
# 16. [PyGame](#pygame)
# 17. [Pytest](#pytest)
# 18. [PyTorch](#pytorch)
# 19. [Qt Designer](#qt-designer)
# 20. [React Py](#react-py)
# 21. [Requests](#requests)
# 22. [Scikit-learn](#scikit-learn)
# 23. [SciPy](#scipy)
# 24. [Scrapy](#scrapy)
# 25. [Seaborn](#seaborn)
# 26. [SQLAlchemy](#sqlalchemy)
# 27. [Statsmodels](#statsmodels)
# 28. [SymPy](#sympy)
# 29. [TensorFlow](#tensorflow)
# 30. [Tkinter](#tkinter)
# 31. [Twisted](#twisted)
#
# ---
#
# ### 1. Asyncio
# - **Descripción**: Biblioteca estándar de Python para la programación asíncrona, utilizada para escribir código concurrente usando la sintaxis `async` y `await`.
# - **Link**: [Asyncio](https://docs.python.org/3/library/asyncio.html)
#
# ### 2. Beautiful Soup
# - **Descripción**: Biblioteca que facilita la extracción de datos de archivos HTML y XML, proporcionando Pythonic idioms para iterar, buscar y modificar el parse tree.
# - **Link**: [Beautiful Soup](https://pypi.org/project/beautifulsoup4/)
#
# ### 3. Bokeh
# - **Descripción**: Biblioteca para la creación de visualizaciones interactivas y atractivas en navegadores web.
# - **Link**: [Bokeh](https://bokeh.org/)
#
# ### 4. Dash
# - **Descripción**: Framework de Python para crear aplicaciones web analíticas e interactivas, construido sobre Flask, Plotly.js y React.js.
# - **Link**: [Dash](https://dash.plotly.com/)
#
# ### 5. Django
# - **Descripción**: Framework web de alto nivel que promueve el desarrollo rápido y el diseño limpio y pragmático.
# - **Link**: [Django](https://www.djangoproject.com/)
#
# ### 6. Flask
# - **Descripción**: Microframework para Python basado en Werkzeug y Jinja2, utilizado para construir aplicaciones web rápidamente.
# - **Link**: [Flask](https://flask.palletsprojects.com/en/3.0.x/)
#
# ### 7. Hugging Face Transformers
# - **Descripción**: Biblioteca para el uso de modelos de aprendizaje profundo preentrenados en tareas de procesamiento del lenguaje natural.
# - **Link**: [Hugging Face Transformers](https://huggingface.co/docs/transformers/en/index)
#
# ### 8. Keras
# - **Descripción**: API de redes neuronales de alto nivel, escrita en Python y capaz de ejecutarse sobre TensorFlow, Microsoft Cognitive Toolkit, Theano, y PlaidML.
# - **Link**: [Keras](https://keras.io/)
#
# ### 9. Matplotlib
# - **Descripción**: Biblioteca de trazado 2D que produce figuras de calidad de publicación en una variedad de formatos impresos y entornos interactivos.
# - **Link**: [Matplotlib](https://matplotlib.org/)
#
# ### 10. NLTK (Natural Language Toolkit)
# - **Descripción**: Plataforma para la construcción de programas de procesamiento de lenguaje natural en Python.
# - **Link**: [NLTK](https://www.nltk.org/)
#
# ### 11. NumPy
# - **Descripción**: Biblioteca fundamental para la computación científica en Python. Proporciona soporte para arrays grandes y multidimensionales.
# - **Link**: [NumPy](https://numpy.org/)
#
# ### 12. OpenCV
# - **Descripción**: Biblioteca de código abierto para visión por computadora que proporciona herramientas para el procesamiento de imágenes y videos.
# - **Link**: [OpenCV](https://opencv.org/)
#
# ### 13. Pandas
# - **Descripción**: Biblioteca de análisis de datos y estructuras de datos que facilita la manipulación y el análisis de datos estructurados.
# - **Link**: [Pandas](https://pandas.pydata.org/)
#
# ### 14. Pillow
# - **Descripción**: Biblioteca de procesamiento de imágenes en Python, una versión mejorada de la biblioteca Python Imaging Library (PIL).
# - **Link**: [Pillow](https://python-pillow.org/)
#
# ### 15. Plotly
# - **Descripción**: Biblioteca de gráficos interactivos que permite la creación de gráficos interactivos y detallados.
# - **Link**: [Plotly](https://plotly.com/python/)
#
# ### 16. PyGame
# - **Descripción**: Conjunto de módulos de Python diseñados para la escritura de videojuegos, incluye gráficos y sonido.
# - **Link**: [PyGame](https://www.pygame.org/)
#
# ### 17. Pytest
# - **Descripción**: Framework de pruebas para Python que facilita la escritura de pruebas simples y escalables para aplicaciones de Python.
# - **Link**: [Pytest](https://docs.pytest.org/en/8.2.x/)
#
# ### 18. PyTorch
# - **Descripción**: Biblioteca de aprendizaje automático que proporciona un reemplazo de tensor de NumPy con fuerte aceleración de GPU.
# - **Link**: [PyTorch](https://pytorch.org/)
#
# ### 19. Qt Designer
# - **Descripción**: Herramienta de diseño para crear interfaces gráficas de usuario (GUI) de manera visual para aplicaciones Qt.
# - **Link**: [Qt Designer](https://doc.qt.io/qt-5/qtdesigner-manual.html)
#
# ### 20. React Py
# - **Descripción**: Biblioteca para construir interfaces de usuario en Python sin necesidad de JavaScript.
# - **Link**: [ReactPy](https://reactpy.dev/docs/index.html)
#
# ### 21. Requests
# - **Descripción**: Biblioteca HTTP simple y elegante para Python, que facilita enviar solicitudes HTTP/1.1.
# - **Link**: [Requests](https://pypi.org/project/requests/)
#
# ### 22. Scikit-learn
# - **Descripción**: Biblioteca de aprendizaje automático que ofrece herramientas simples y eficientes para el análisis de datos.
# - **Link**: [Scikit-learn](https://scikit-learn.org/stable/)
#
# ### 23. SciPy
# - **Descripción**: Biblioteca que utiliza NumPy y proporciona herramientas para matemáticas avanzadas, ciencia y ingeniería.
# - **Link**: [SciPy](https://www.scipy.org/)
#
# ### 24. Scrapy
# - **Descripción**: Framework para la extracción de datos de sitios web, utilizado para la construcción de arañas web.
# - **Link**: [Scrapy](https://scrapy.org/)
#
# ### 25. Seaborn
# - **Descripción**: Biblioteca para la visualización de datos basada en Matplotlib.
# - **Link**: [Seaborn](https://seaborn.pydata.org/)
#
# ### 26. SQLAlchemy
# - **Descripción**: Biblioteca SQL para Python que proporciona un ORM (Object-Relational Mapping).
# - **Link**: [SQLAlchemy](https://www.sqlalchemy.org/)
#
# ### 27. Statsmodels
# - **Descripción**: Biblioteca que proporciona clases y funciones para la estimación de modelos estadísticos.
# - **Link**: [Statsmodels](https://www.statsmodels.org/)
#
# ### 28. SymPy
# - **Descripción**: Biblioteca para la computación simbólica en Python.
# - **Link**: [SymPy](https://www.sympy.org/en/index.html)
#
# ### 29. TensorFlow
# - **Descripción**: Plataforma de código abierto para el aprendizaje automático desarrollada por Google.
# - **Link**: [TensorFlow](https://www.tensorflow.org/)
#
# ### 30. Tkinter
# - **Descripción**: Paquete estándar de interfaces gráficas de usuario (GUI) en Python.
# - **Link**: [Tkinter](https://docs.python.org/3/library/tkinter.html)
#
# ### 31. Twisted
# - **Descripción**: Framework de red para Python que facilita la creación de aplicaciones de red asincrónicas.
# - **Link**: [Twisted](https://twisted.org/)
